# %% [markdown]
# ### Inference optimization

# %%
# !python ../scripts/benchmark_onnx.py --model ../deployment/model.onnx
# Out:
# Loading ONNX model: ../deployment/model.onnx
# Input: points
# Outputs: ['center', 'size', 'yaw']
# Providers: ['CPUExecutionProvider']
# Running benchmark...
# Results:
# Average inference time: 3.060 ms
# FPS: 326.75
#
# Output shapes:
# center: (1, 3)
# size: (1, 3)
# yaw: (1,)

# %%
# !python ../scripts/benchmark_compare.py --onnx ../deployment/model.onnx --model ../outputs/models/best_model_diou_lr_cos.pth
# Out:
# Device: cpu
#
#  Benchmarking PyTorch...
# Benchmarking ONNX...
#
# Comparing outputs...
#  RESULTS
# ----------------------------------------
# PyTorch Time: 4.961 ms
# ONNX Time:    2.517 ms
# Speedup:      1.97x
#
# Numerical Differences:
#
# center:
#   mean_abs: 0.000000
#   max_abs:  0.000000
#   mean_rel: 0.000001
#   max_rel:  0.000003
#
# size:
#   mean_abs: 0.000006
#   max_abs:  0.000009
#   mean_rel: 0.000001
#   max_rel:  0.000001
#
# yaw:
#   mean_abs: 0.000001
#   max_abs:  0.000001
#   mean_rel: 0.000001
#   max_rel:  0.000001
